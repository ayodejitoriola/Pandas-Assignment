# %% [markdown]
# ''' Exercise 1 (Using the flight.csvDownload flight.csv)
#
# - Finding the number of canceled flights for every airline per weekday
# - Finding the number and percentage of canceled and diverted flights for every airline
# per weekday
# - For each origin and destination, finding the total number of flights, the number and
# percentage of canceled flights, and the average and variance of the airtime'''

# %%
import pandas as pd

# %%
Flight = pd.read_csv(r"C:\Users\ayode\Downloads\flights-2.csv")
Flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
#1C

Flight.groupby(['DEST_AIR','ORG_AIR'] ).agg({'SCHED_DEP':'sum','CANCELLED':'count','AIR_TIME':'mean'})
# Out:
#                   SCHED_DEP  CANCELLED    AIR_TIME
# DEST_AIR ORG_AIR
# ABE      ATL          46567         31   96.387097
#          ORD          33747         24   87.608696
# ABI      DFW         121482         74   30.597222
# ABQ      ATL          25426         16  170.500000
#          DEN          66858         46   54.152174
# ...                     ...        ...         ...
# XNA      IAH          52362         39   69.351351
#          MSP          16794         14   90.642857
#          ORD         118981         86   79.987654
#          SFO           2660          2  173.500000
# YUM      PHX          66663         53   32.423077
#
# [1130 rows x 3 columns]

# %%
Flight.columns
# Out:
# Index(['MONTH', 'DAY', 'WEEKDAY', 'AIRLINE', 'ORG_AIR', 'DEST_AIR',
#        'SCHED_DEP', 'DEP_DELAY', 'AIR_TIME', 'DIST', 'SCHED_ARR', 'ARR_DELAY',
#        'DIVERTED', 'CANCELLED'],
#       dtype='object')

# %%
Flight.describe(include='all')
# Out:
#                MONTH           DAY       WEEKDAY AIRLINE ORG_AIR DEST_AIR  \
# count   58492.000000  58492.000000  58492.000000   58492   58492    58492
# unique           NaN           NaN           NaN      14      10      271
# top              NaN           NaN           NaN      DL     ATL      LAX
# freq             NaN           NaN           NaN   10601   10413     1991
# mean        6.220646     15.702096      3.926862     NaN     NaN      NaN
# std         3.358484      8.760846      1.995777     NaN     NaN      NaN
# min         1.000000      1.000000      1.000000     NaN     NaN      NaN
# 25%         3.000000      8.000000      2.000000     NaN     NaN      NaN
# 50%         6.000000     16.000000      4.000000     NaN     NaN      NaN
# 75%         9.000000     23.000000      6.000000     NaN     NaN      NaN
# max        12.000000     31.000000      7.000000     NaN     NaN      NaN
#
#            SCHED_DEP     DEP_DELAY      AIR_TIME          DIST     SCHED_ARR  \
# ...

# %%
Flight.tail()
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 58487     166.0  1464       1045      -19.0         0          0
# 58488      71.0   414       2050        4.0         0          0
# 58489      46.0   262       1956       -5.0         0          0
# 58490     124.0   907        855       34.0         0          0
# 58491      73.0   522       1146       -1.0         0          0

# %%
Flight.isna().sum()
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %%
##1(A).
Finding the number of canceled flights for every airline per weekday
Flight.groupby('AIRLINE')['CANCELLED','WEEKDAY'].sum()
# Out:
# C:\Users\ayode\AppData\Local\Temp\ipykernel_12052\1400683430.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Flight.groupby('AIRLINE')['CANCELLED','WEEKDAY'].sum()
#          CANCELLED  WEEKDAY
# AIRLINE
# AA             154    35484
# AS               0     3027
# B6               1     2194
# DL              38    41485
# EV             146    23007
# F9              10     5278
# HA               0      420
# MQ             152    13546
# NK              25     6074
# OO             142    25847
# UA              93    30167
# US              21     6563
# VX               6     3897
# WN              93    32701

# %%
##1(B)Finding the number and percentage of canceled and diverted flights for every airline per weekday
number=Flight.groupby('AIRLINE')['CANCELLED','DIVERTED','WEEKDAY'].sum()
number
# Out:
# C:\Users\ayode\AppData\Local\Temp\ipykernel_12052\1664949749.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   number=Flight.groupby('AIRLINE')['CANCELLED','DIVERTED','WEEKDAY'].sum()
#          CANCELLED  DIVERTED  WEEKDAY
# AIRLINE
# AA             154        26    35484
# AS               0         0     3027
# B6               1         2     2194
# DL              38        24    41485
# EV             146        15    23007
# F9              10         2     5278
# HA               0         1      420
# MQ             152         5    13546
# NK              25         5     6074
# OO             142        21    25847
# UA              93        19    30167
# US              21         1     6563
# VX               6         1     3897
# WN              93        15    32701

# %%
#1C

Flight.groupby(['DEST_AIR','ORG_AIR'] ).agg({'SCHED_DEP':'sum','CANCELLED':'count','AIR_TIME':'mean'})
# Out:
#                   SCHED_DEP  CANCELLED    AIR_TIME
# DEST_AIR ORG_AIR
# ABE      ATL          46567         31   96.387097
#          ORD          33747         24   87.608696
# ABI      DFW         121482         74   30.597222
# ABQ      ATL          25426         16  170.500000
#          DEN          66858         46   54.152174
# ...                     ...        ...         ...
# XNA      IAH          52362         39   69.351351
#          MSP          16794         14   90.642857
#          ORD         118981         86   79.987654
#          SFO           2660          2  173.500000
# YUM      PHX          66663         53   32.423077
#
# [1130 rows x 3 columns]

# %% [markdown]
# '''Exercise 2
# - Using the covid_subset.txtDownload covid_subset.txt
#     - load the data
#     - find the dimensions of the data
#     - select the following variables and save them in a new dataframe: continent, locations, total_cases, total_deaths,
#         gdp_per_capita, tests_per_case, life_expectancy,female_smokers, male_smokers, diabetes_prevalence.
#     - Find the missing values in the variables selected
#
# * Devise an appropriate approach with reasonable explanation on how to handle the missing values.
# - Find the Continent with the highest total cases and total deaths of coronavirus
# - Which Country has the highest number of deaths?
# - Which Continent has the highest number of deaths and total cases of Covid-19?'''

# %%
import pandas as pd

# %%
#Ai.Load the data
Covid_subset=pd.read_csv(r"C:\Users\ayode\Downloads\covid_subset-1.txt")
Covid_subset
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 0        AFG      Asia  Afghanistan  2019-12-31          0.0        0.0
# 1        AFG      Asia  Afghanistan  2020-01-01          0.0        0.0
# 2        AFG      Asia  Afghanistan  2020-01-02          0.0        0.0
# 3        AFG      Asia  Afghanistan  2020-01-03          0.0        0.0
# 4        AFG      Asia  Afghanistan  2020-01-04          0.0        0.0
# ..       ...       ...          ...         ...          ...        ...
# 200      AFG      Asia  Afghanistan  2020-07-28      36368.0      105.0
# 201      AFG      Asia  Afghanistan  2020-07-29      36471.0      103.0
# 202      AFG      Asia  Afghanistan  2020-07-30      36471.0        0.0
# 203      AFG      Asia  Afghanistan  2020-07-31      36542.0       71.0
# 204      AFG      Asia  Afghanistan  2020-08-01      36710.0      168.0
#
#      total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
#Aii. Find the dimensions of the data
Covid_subset.shape
# Out:
# (205, 36)

# %%
Covid_subset.isna().sum()
# Out:
# iso_code                             0
# continent                            0
# location                             0
# date                                 0
# total_cases                          0
# new_cases                            0
# total_deaths                         0
# new_deaths                           0
# total_cases_per_million              0
# new_cases_per_million                0
# total_deaths_per_million             0
# new_deaths_per_million               0
# new_tests                          205
# total_tests                        205
# total_tests_per_thousand           205
# new_tests_per_thousand             205
# new_tests_smoothed                 205
# new_tests_smoothed_per_thousand    205
# tests_per_case                     205
# positive_rate                      205
# tests_units                        205
# stringency_index                     1
# population                           0
# population_density                   0
# ...

# %%
Covid_subset.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
#Aiii. select the following variables and save them in a new dataframe: continent, locations, total_cases, 
# total_deaths, gdp_per_capita, tests_per_case, life_expectancy,female_smokers, male_smokers, diabetes_prevalence
Covid=Covid_subset[["continent", "location", "total_cases", "total_deaths", "gdp_per_capita", "tests_per_case", 
                    "life_expectancy", "female_smokers", "male_smokers", "diabetes_prevalence"]]
Covid
# Out:
#     continent     location  total_cases  total_deaths  gdp_per_capita  \
# 0        Asia  Afghanistan          0.0           0.0        1803.987
# 1        Asia  Afghanistan          0.0           0.0        1803.987
# 2        Asia  Afghanistan          0.0           0.0        1803.987
# 3        Asia  Afghanistan          0.0           0.0        1803.987
# 4        Asia  Afghanistan          0.0           0.0        1803.987
# ..        ...          ...          ...           ...             ...
# 200      Asia  Afghanistan      36368.0        1270.0        1803.987
# 201      Asia  Afghanistan      36471.0        1271.0        1803.987
# 202      Asia  Afghanistan      36471.0        1271.0        1803.987
# 203      Asia  Afghanistan      36542.0        1271.0        1803.987
# 204      Asia  Afghanistan      36710.0        1283.0        1803.987
#
#      tests_per_case  life_expectancy  female_smokers  male_smokers  \
# ...

# %%
#Aiv. Find the missing values in the variables selected
Covid.isna().sum()
# Out:
# continent                0
# location                 0
# total_cases              0
# total_deaths             0
# gdp_per_capita           0
# tests_per_case         205
# life_expectancy          0
# female_smokers         205
# male_smokers           205
# diabetes_prevalence      0
# dtype: int64

# %%
#B
# The missing values will be dropped due to no value in any of the selected values, 
# we have 205 row and the missing rows are also 205

Covid.drop(['tests_per_case','female_smokers','male_smokers'],axis=1, inplace=True)
# Out:
# C:\Users\ayode\AppData\Local\Temp\ipykernel_12052\2948633607.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Covid.drop(['tests_per_case','female_smokers','male_smokers'],axis=1, inplace=True)

# %%
Covid.isna().sum()
# Out:
# continent              0
# location               0
# total_cases            0
# total_deaths           0
# gdp_per_capita         0
# life_expectancy        0
# diabetes_prevalence    0
# dtype: int64

# %%
Covid_subset['male_smokers'].max()
# Out:
# nan

# %%
Covid.describe()
# Out:
#         total_cases  total_deaths  gdp_per_capita  tests_per_case  \
# count    205.000000    205.000000    2.050000e+02             0.0
# mean   10164.204878    265.068293    1.803987e+03             NaN
# std    13665.318767    394.376941    3.418954e-12             NaN
# min        0.000000      0.000000    1.803987e+03             NaN
# 25%        0.000000      0.000000    1.803987e+03             NaN
# 50%     1031.000000     35.000000    1.803987e+03             NaN
# 75%    22143.000000    405.000000    1.803987e+03             NaN
# max    36710.000000   1283.000000    1.803987e+03             NaN
#
#        life_expectancy  female_smokers  male_smokers  diabetes_prevalence
# count     2.050000e+02             0.0           0.0         2.050000e+02
# mean      6.483000e+01             NaN           NaN         9.590000e+00
# std       5.698257e-14             NaN           NaN         3.383340e-14
# min       6.483000e+01             NaN           NaN         9.590000e+00
# ...

# %%
#C. Find the Continent with the highest total cases and total deaths of coronavirus
Covid.groupby('continent')['total_cases','total_deaths'].max()
# Out:
# C:\Users\ayode\AppData\Local\Temp\ipykernel_11780\1164919698.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Covid.groupby('continent')['total_cases','total_deaths'].max()
#            total_cases  total_deaths
# continent
# Asia           36710.0        1283.0

# %%
#D. Which Country has the highest number of deaths?
Covid.groupby('location')['total_deaths'].max()
# Out:
# location
# Afghanistan    1283.0
# Name: total_deaths, dtype: float64

# %%
#E. Which Continent has the highest number of deaths and total cases of Covid-19
Covid.groupby('continent').agg({'total_deaths':'max','total_cases':'sum'})
# Out:
#            total_deaths  total_cases
# continent
# Asia             1283.0    2083662.0
